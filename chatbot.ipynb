# %%
# !pip install requests pillow IPython
# Out:
# ...
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ------------------ --------------------- 30.7/64.9 kB 1.3 MB/s eta 0:00:01
#    ------------------ --------------------- 30.7/64.9 kB 1.3 MB/s eta 0:00:01
#    ------------------ --------------------- 30.7/64.9 kB 1.3 MB/s eta 0:00:01
#    ------------------ --------------------- 30.7/64.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 64.9/64.9 kB 249.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.6 MB 3.2 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/2.6 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/2.6 MB 2.6 MB/s eta 0:00:01
# ...

# %%
# First, install necessary packages


import requests
from PIL import Image
from IPython.display import display, Image as IPImage
import base64
import io

# Replace with your actual API key
API_KEY = 'AIzaSyDvWSxEts3K3bE_pOFvhXX2vTnZxOetQO8'
API_ENDPOINT = 'https://esm.run/@google/generative-ai'  # Replace with actual endpoint

def encode_image(image_path):
    """Encode image to base64."""
    with open(image_path, "rb") as img_file:
        base64_encoded = base64.b64encode(img_file.read()).decode('utf-8')
    return base64_encoded

def send_message(prompt, image_base64=None):
    """Send text and image to the generative AI model."""
    headers = {
        'Authorization': f'Bearer {API_KEY}',
        'Content-Type': 'application/json'
    }

    payload = {
        'prompt': prompt,
        'image': image_base64
    }

    response = requests.post(API_ENDPOINT, json=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": response.text}

def display_image(image_base64):
    """Display image from base64 string."""
    image_data = base64.b64decode(image_base64)
    image = Image.open(io.BytesIO(image_data))
    display(image)

def main():
    # Example prompt and image path
    prompt = "Describe the uploaded image."
    image_path = 'image.jpg'  # Replace with your image path

    # Encode image
    image_base64 = encode_image(image_path)

    # Send request
    response = send_message(prompt, image_base64)

    # Handle response
    if 'error' in response:
        print(f"Error: {response['error']}")
    else:
        print(f"Response: {response}")

        # Display image if included in the response
        if 'image' in response:
            display_image(response['image'])

# Run the main function
main()
# Out:
# Error: Method Not Allowed

# %%
import requests
from PIL import Image
from IPython.display import display
import base64
import io

# Replace with your actual API key
API_KEY = 'AIzaSyDvWSxEts3K3bE_pOFvhXX2vTnZxOetQO8'
API_ENDPOINT = 'https://esm.run/@google/generative-ai'  # Replace with actual endpoint

def encode_image(image_path):
    """Encode image to base64."""
    with open(image_path, "rb") as img_file:
        base64_encoded = base64.b64encode(img_file.read()).decode('utf-8')
    return base64_encoded

def send_message(prompt, image_base64=None):
    """Send text and image to the generative AI model."""
    headers = {
        'Authorization': f'Bearer {API_KEY}',
        'Content-Type': 'application/json'
    }

    payload = {
        'prompt': prompt,
        'image': image_base64
    }

    # Make sure you use the correct HTTP method and endpoint
    response = requests.post(API_ENDPOINT, json=payload, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": response.text}

def display_image(image_base64):
    """Display image from base64 string."""
    image_data = base64.b64decode(image_base64)
    image = Image.open(io.BytesIO(image_data))
    display(image)

def main():
    # Example prompt and image path
    prompt = "Describe the uploaded image."
    image_path = None  # Set to None if no image is provided

    if image_path:
        # Encode image if path is provided
        image_base64 = encode_image(image_path)
    else:
        # No image to encode
        image_base64 = None

    # Send request
    response = send_message(prompt, image_base64)

    # Handle response
    if 'error' in response:
        print(f"Error: {response['error']}")
    else:
        print(f"Response: {response}")

        # Display image if included in the response
        if 'image' in response:
            display_image(response['image'])

# Run the main function
main()
# Out:
# Error: Method Not Allowed

# %%
# !pip install -U -q google-generativeai # Install the Python SDK
# Out:
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
import google.generativeai as genai

genai.configure(api_key="'AIzaSyDvWSxEts3K3bE_pOFvhXX2vTnZxOetQO8'")
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content("Give me python code to sort a list")
print(response.text)
